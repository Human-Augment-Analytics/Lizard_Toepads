# %%
from ultralytics import YOLO
import numpy as np
import cv2
import torch
from pathlib import Path
import albumentations as A
from albumentations.pytorch import ToTensorV2
from torch import nn
import torch
from torch.utils.data import DataLoader, Dataset, random_split
from sklearn.model_selection import train_test_split
import torch.nn.functional as F
import time
import matplotlib.pyplot as plt
import timm
import torch.optim as optim

# %%
NUM_LANDMARKS = 9

class ViTLandmark(nn.Module):
    def __init__(self, pretrained=True):
        super().__init__()
        self.backbone = timm.create_model('vit_small_patch16_224', pretrained=pretrained)

        in_features = self.backbone.head.in_features
        self.backbone.head = nn.Identity()

        self.head = nn.Sequential(
            nn.Linear(in_features, 2048),
            nn.LayerNorm(2048),
            nn.ReLU(),
            nn.Linear(2048, 1024),
            nn.LayerNorm(1024),
            nn.ReLU(),
            nn.Linear(1024, NUM_LANDMARKS * 2)
        )

    def forward(self, x):
        #print(x.shape)
        #print(x.dtype, x.min().item(), x.max().item())
        #print(torch.isnan(x).any(), torch.isinf(x).any())
        features = self.backbone(x)
        coords = torch.sigmoid(self.head(features))
        return coords

class ViTDataset(Dataset):
    def __init__(self, folder):
        self.folder = Path(folder)
        self.files = sorted(self.folder.glob("*.pt"))

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        data = torch.load(self.files[idx])
        img = data["image"].float()
        keypoints = data["keypoints"].float()
        keypoints = keypoints / 224
    
        return img, keypoints

# %%
device = 'cuda'

model = ViTLandmark(pretrained=True).to(device)
b_params = model.backbone.parameters()
h_params = model.head.parameters()
optimizer = optim.SGD([
    {'params': b_params, 'lr': 1e-5},
    {'params': h_params, 'lr': 1e-3},
], momentum=0.9)

criterion = nn.SmoothL1Loss()
dataset = ViTDataset(f"../data/training_data/vit")
val_fraction = 0.1
val_len = int(len(dataset)*val_fraction)
train_len = len(dataset) - val_len
train_dataset, val_dataset = random_split(dataset, [train_len, val_len])
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=0, pin_memory=True)

val_loader = DataLoader(val_dataset, batch_size=16, shuffle=True, num_workers=0, pin_memory=True)
# Out:
# C:\Users\axu16\anaconda3\envs\lizard\Lib\site-packages\torch\cuda\__init__.py:287: UserWarning:
# NVIDIA GeForce RTX 5080 with CUDA capability sm_120 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_37 sm_50 sm_60 sm_61 sm_70 sm_75 sm_80 sm_86 sm_90 compute_37.
# If you want to use the NVIDIA GeForce RTX 5080 GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   warnings.warn(

# %%
for p in model.backbone.parameters():
    p.requires_grad = False

best_pixel_error = float('inf')
for epoch in range(10):
    model.train()
    total_loss = 0
    bc = 1
    for images, keypoints in train_loader:
        images = images.to(device)
        keypoints = keypoints.to(device)
        k_flat = keypoints.view(keypoints.size(0), -1)
        optimizer.zero_grad()
        preds = model(images)
        loss = criterion(preds, k_flat)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        total_loss += loss.item()
        print(f"\rBatch {bc}/{len(train_loader)}, Loss {loss}", end='')
        bc += 1
        
    avg_loss = total_loss / len(train_loader)
    print(f"Epoch {epoch}/10 - Loss: {avg_loss:.6f}")

    model.eval()
    val_loss = 0
    total_pixel_error = 0
    val_batches = 0
    with torch.no_grad():
        for images, keypoints in val_loader:
            images = images.to(device)
            keypoints = keypoints.to(device)
            k_flat = keypoints.view(keypoints.size(0), -1)

            preds = model(images)
            loss = criterion(preds, k_flat)
            val_loss += loss.item()

            # pixel error for interpretability
            preds_px = preds * 224
            k_px = k_flat * 224
            pixel_error = torch.mean(torch.abs(preds_px - k_px)).item()
            total_pixel_error += pixel_error
            val_batches += 1

    avg_val_loss = val_loss / val_batches
    avg_pixel_error = total_pixel_error / val_batches
    print(f"Epoch {epoch}/10 - Val Loss: {avg_val_loss:.6f}, Avg Pixel Error: {avg_pixel_error:.2f}")

    # ----------------------------
    # Checkpoint best model
    # ----------------------------
    if avg_pixel_error < best_pixel_error:
        best_pixel_error = avg_pixel_error
        torch.save(model.state_dict(), "best_vit_landmark.pth")
        print(f"New best model saved with pixel error {best_pixel_error:.2f}")
# Out:
# Batch 7/92, Loss 0.024677449837327003

# %%
small_dataset, _ = random_split(train_dataset, [16, len(train_dataset)-16])
small_loader = DataLoader(small_dataset, batch_size=4, shuffle=True)

for p in model.backbone.parameters():
    p.requires_grad = False

for epoch in range(20):
    for images, keypoints in small_loader:
        images, keypoints = images.to(device), keypoints.to(device)
        optimizer.zero_grad()

        # -------------------
        # Forward pass
        # -------------------
        with torch.autograd.detect_anomaly():
            preds = model(images)
    
            # -------------------
            # Diagnostics BEFORE loss.backward()
            # -------------------
            with torch.no_grad():
                print(f"\n=== Diagnostics epoch {epoch} ===")
                print("Images: min %.3f, max %.3f, mean %.3f" % (images.min().item(), images.max().item(), images.mean().item()))
                print("Keypoints: min %.3f, max %.3f, mean %.3f" % (keypoints.min().item(), keypoints.max().item(), keypoints.mean().item()))
                print("Preds: min %.3f, max %.3f, mean %.3f" % (preds.min().item(), preds.max().item(), preds.mean().item()))
    
            # -------------------
            # Compute loss
            # -------------------
            loss = criterion(preds, keypoints.view(keypoints.size(0), -1))
    
            # -------------------
            # Diagnostics AFTER backward() (grad check)
            # -------------------
            loss.backward()
            total_grad = sum(p.grad.abs().sum().item() for p in model.parameters() if p.grad is not None)
            print("Loss:", loss.item(), "| Total grad sum:", total_grad)

        # optimizer step
        optimizer.step()
# Out:
# C:\Users\axu16\AppData\Local\Temp\ipykernel_17924\3755362475.py:15: UserWarning: Anomaly Detection has been enabled. This mode will increase the runtime and should only be enabled for debugging.
#   with torch.autograd.detect_anomaly():
# === Diagnostics epoch 0 ===
# Images: min -2.118, max 2.082, mean -0.021
# Keypoints: min 0.057, max 0.955, mean 0.533
# Preds: min 0.285, max 0.627, mean 0.496
# Loss: 0.03823692351579666 | Total grad sum: 119.8822019174695
#
# === Diagnostics epoch 0 ===
# Images: min -2.118, max 1.856, mean -0.706
# Keypoints: min 0.031, max 0.980, mean 0.527
# Preds: min 0.285, max 0.627, mean 0.496
# Loss: 0.034270405769348145 | Total grad sum: 109.39575120806694
#
# === Diagnostics epoch 0 ===
# Images: min -2.118, max 2.047, mean -0.378
# Keypoints: min 0.046, max 0.939, mean 0.516
# Preds: min 0.286, max 0.627, mean 0.496
# Loss: 0.03586568683385849 | Total grad sum: 130.356221601367
#
# === Diagnostics epoch 0 ===
# Images: min -2.118, max 1.995, mean -0.256
# Keypoints: min 0.062, max 0.952, mean 0.520
# Preds: min 0.288, max 0.626, mean 0.496
# Loss: 0.038210418075323105 | Total grad sum: 147.0216919630766
#
# === Diagnostics epoch 1 ===
# Images: min -2.118, max 2.013, mean -0.488
# Keypoints: min 0.079, max 0.939, mean 0.510
# Preds: min 0.290, max 0.625, mean 0.497
# Loss: 0.03171553835272789 | Total grad sum: 121.24930156767368
#
# === Diagnostics epoch 1 ===
# Images: min -2.118, max 2.082, mean 0.428
# Keypoints: min 0.046, max 0.938, mean 0.526
# Preds: min 0.293, max 0.625, mean 0.497
# Loss: 0.040161337703466415 | Total grad sum: 122.71838278323412
#
# === Diagnostics epoch 1 ===
# Images: min -2.118, max 1.995, mean -0.538
# Keypoints: min 0.049, max 0.980, mean 0.525
# Preds: min 0.296, max 0.625, mean 0.498
# Loss: 0.034129127860069275 | Total grad sum: 128.6408709026873
#
# === Diagnostics epoch 1 ===
# Images: min -2.118, max 1.995, mean -0.762
# Keypoints: min 0.031, max 0.978, mean 0.535
# Preds: min 0.299, max 0.626, mean 0.498
# Loss: 0.03313286975026131 | Total grad sum: 127.40453830361366
#
# === Diagnostics epoch 2 ===
# Images: min -2.118, max 2.082, mean -0.229
# Keypoints: min 0.031, max 0.978, mean 0.526
# Preds: min 0.303, max 0.626, mean 0.499
# Loss: 0.033961933106184006 | Total grad sum: 109.80848236754537
#
# === Diagnostics epoch 2 ===
# Images: min -2.118, max 1.786, mean -0.508
# Keypoints: min 0.060, max 0.938, mean 0.519
# Preds: min 0.306, max 0.627, mean 0.499
# Loss: 0.029912041500210762 | Total grad sum: 126.17750723659992
#
# === Diagnostics epoch 2 ===
# Images: min -2.118, max 2.047, mean -0.034
# Keypoints: min 0.046, max 0.952, mean 0.512
# Preds: min 0.310, max 0.627, mean 0.500
# Loss: 0.03385937958955765 | Total grad sum: 127.8338954821229
#
# === Diagnostics epoch 2 ===
# Images: min -2.118, max 2.013, mean -0.590
# Keypoints: min 0.049, max 0.980, mean 0.539
# Preds: min 0.314, max 0.628, mean 0.501
# Loss: 0.029113398864865303 | Total grad sum: 126.4422414638102
#
# === Diagnostics epoch 3 ===
# Images: min -2.118, max 2.013, mean -0.578
# Keypoints: min 0.049, max 0.980, mean 0.516
# Preds: min 0.319, max 0.628, mean 0.502
# Loss: 0.029035503044724464 | Total grad sum: 109.79216437414289
#
# === Diagnostics epoch 3 ===
# Images: min -2.118, max 2.082, mean -0.291
# Keypoints: min 0.031, max 0.978, mean 0.534
# Preds: min 0.323, max 0.628, mean 0.502
# Loss: 0.03070257417857647 | Total grad sum: 81.05055240541697
#
# === Diagnostics epoch 3 ===
# Images: min -2.118, max 2.047, mean -0.011
# Keypoints: min 0.057, max 0.955, mean 0.516
# Preds: min 0.328, max 0.629, mean 0.503
# Loss: 0.027843032032251358 | Total grad sum: 113.49075255170465
#
# === Diagnostics epoch 3 ===
# Images: min -2.118, max 1.995, mean -0.481
# Keypoints: min 0.060, max 0.952, mean 0.531
# Preds: min 0.333, max 0.629, mean 0.504
# Loss: 0.026098236441612244 | Total grad sum: 112.30483319982886
#
# === Diagnostics epoch 4 ===
# Images: min -2.118, max 1.525, mean -1.124
# Keypoints: min 0.031, max 0.978, mean 0.518
# Preds: min 0.338, max 0.629, mean 0.505
# Loss: 0.02435474842786789 | Total grad sum: 70.77188504487276
#
# === Diagnostics epoch 4 ===
# Images: min -2.118, max 2.013, mean -0.571
# Keypoints: min 0.057, max 0.955, mean 0.532
# Preds: min 0.343, max 0.630, mean 0.505
# Loss: 0.023059044033288956 | Total grad sum: 107.6526700258255
#
# === Diagnostics epoch 4 ===
# Images: min -2.118, max 2.082, mean 0.039
# Keypoints: min 0.046, max 0.980, mean 0.529
# Preds: min 0.349, max 0.630, mean 0.506
# Loss: 0.02814842201769352 | Total grad sum: 88.33856381103396
#
# === Diagnostics epoch 4 ===
# Images: min -2.118, max 2.047, mean 0.295
# Keypoints: min 0.060, max 0.938, mean 0.517
# Preds: min 0.354, max 0.631, mean 0.507
# Loss: 0.025124022737145424 | Total grad sum: 111.35267766937613
#
# === Diagnostics epoch 5 ===
# Images: min -2.118, max 2.082, mean -0.261
# Keypoints: min 0.062, max 0.952, mean 0.527
# Preds: min 0.359, max 0.631, mean 0.508
# Loss: 0.02375359833240509 | Total grad sum: 81.46094013750553
#
# === Diagnostics epoch 5 ===
# Images: min -2.118, max 2.013, mean -0.388
# Keypoints: min 0.057, max 0.955, mean 0.530
# Preds: min 0.365, max 0.631, mean 0.509
# Loss: 0.02119017019867897 | Total grad sum: 96.95808535441756
#
# === Diagnostics epoch 5 ===
# Images: min -2.118, max 1.856, mean -1.170
# Keypoints: min 0.031, max 0.980, mean 0.525
# Preds: min 0.370, max 0.631, mean 0.509
# Loss: 0.021658871322870255 | Total grad sum: 49.827732825651765
#
# === Diagnostics epoch 5 ===
# Images: min -2.118, max 2.047, mean 0.458
# Keypoints: min 0.046, max 0.934, mean 0.515
# Preds: min 0.375, max 0.631, mean 0.510
# Loss: 0.02328725904226303 | Total grad sum: 99.67782852426171
#
# === Diagnostics epoch 6 ===
# Images: min -2.118, max 2.047, mean 0.463
# Keypoints: min 0.031, max 0.978, mean 0.514
# Preds: min 0.381, max 0.631, mean 0.511
# Loss: 0.025047579780220985 | Total grad sum: 87.73397980257869
#
# === Diagnostics epoch 6 ===
# Images: min -2.118, max 1.995, mean -0.905
# Keypoints: min 0.049, max 0.980, mean 0.544
# Preds: min 0.386, max 0.631, mean 0.512
# Loss: 0.016984112560749054 | Total grad sum: 68.08059565722942
#
# === Diagnostics epoch 6 ===
# Images: min -2.118, max 1.995, mean -0.244
# Keypoints: min 0.057, max 0.955, mean 0.516
# Preds: min 0.391, max 0.631, mean 0.512
# Loss: 0.018825167790055275 | Total grad sum: 87.49985079467297
#
# === Diagnostics epoch 6 ===
# Images: min -2.118, max 2.082, mean -0.675
# Keypoints: min 0.065, max 0.939, mean 0.523
# Preds: min 0.396, max 0.633, mean 0.513
# Loss: 0.02029898203909397 | Total grad sum: 34.51157011650503
#
# === Diagnostics epoch 7 ===
# Images: min -2.118, max 2.047, mean -0.131
# Keypoints: min 0.031, max 0.978, mean 0.517
# Preds: min 0.398, max 0.639, mean 0.514
# Loss: 0.020225584506988525 | Total grad sum: 81.50639096461236
#
# === Diagnostics epoch 7 ===
# Images: min -2.118, max 1.995, mean -0.033
# Keypoints: min 0.062, max 0.952, mean 0.520
# Preds: min 0.393, max 0.645, mean 0.514
# Loss: 0.016201013699173927 | Total grad sum: 78.6577608063817
#
# === Diagnostics epoch 7 ===
# Images: min -2.118, max 2.082, mean -0.811
# Keypoints: min 0.049, max 0.980, mean 0.542
# Preds: min 0.389, max 0.651, mean 0.515
# Loss: 0.018466753885149956 | Total grad sum: 44.845661737024784
#
# === Diagnostics epoch 7 ===
# Images: min -2.118, max 2.047, mean -0.385
# Keypoints: min 0.060, max 0.938, mean 0.517
# Preds: min 0.385, max 0.656, mean 0.515
# Loss: 0.01842554472386837 | Total grad sum: 82.80711110681295
#
# === Diagnostics epoch 8 ===
# Images: min -2.118, max 1.995, mean -0.043
# Keypoints: min 0.031, max 0.978, mean 0.514
# Preds: min 0.381, max 0.661, mean 0.516
# Loss: 0.01803835667669773 | Total grad sum: 61.723142094910145
#
# === Diagnostics epoch 8 ===
# Images: min -2.118, max 2.082, mean -0.133
# Keypoints: min 0.060, max 0.938, mean 0.528
# Preds: min 0.377, max 0.666, mean 0.517
# Loss: 0.02060513384640217 | Total grad sum: 34.32079408597201
#
# === Diagnostics epoch 8 ===
# Images: min -2.118, max 2.047, mean -0.476
# Keypoints: min 0.046, max 0.955, mean 0.515
# Preds: min 0.374, max 0.670, mean 0.517
# Loss: 0.01662447489798069 | Total grad sum: 60.5778651535511
#
# === Diagnostics epoch 8 ===
# Images: min -2.118, max 2.013, mean -0.709
# Keypoints: min 0.049, max 0.980, mean 0.540
# Preds: min 0.370, max 0.674, mean 0.518
# Loss: 0.01189574133604765 | Total grad sum: 57.199708212167025
#
# === Diagnostics epoch 9 ===
# Images: min -2.118, max 2.047, mean 0.163
# Keypoints: min 0.046, max 0.980, mean 0.522
# Preds: min 0.365, max 0.678, mean 0.518
# Loss: 0.015013773925602436 | Total grad sum: 71.04920234717429
#
# === Diagnostics epoch 9 ===
# Images: min -2.118, max 1.995, mean -0.644
# Keypoints: min 0.031, max 0.978, mean 0.521
# Preds: min 0.361, max 0.682, mean 0.519
# Loss: 0.016098950058221817 | Total grad sum: 58.499021818861365
#
# === Diagnostics epoch 9 ===
# Images: min -2.118, max 2.082, mean -0.412
# Keypoints: min 0.065, max 0.913, mean 0.532
# Preds: min 0.357, max 0.687, mean 0.519
# Loss: 0.01809566840529442 | Total grad sum: 33.34136737789959
#
# === Diagnostics epoch 9 ===
# Images: min -2.118, max 1.960, mean -0.468
# Keypoints: min 0.060, max 0.938, mean 0.521
# Preds: min 0.353, max 0.690, mean 0.520
# Loss: 0.013958101160824299 | Total grad sum: 63.47422854974866
#
# === Diagnostics epoch 10 ===
# Images: min -2.118, max 2.082, mean 0.153
# Keypoints: min 0.031, max 0.978, mean 0.529
# Preds: min 0.349, max 0.694, mean 0.520
# Loss: 0.022000858560204506 | Total grad sum: 50.892872393131256
#
# === Diagnostics epoch 10 ===
# Images: min -2.118, max 1.995, mean -0.744
# Keypoints: min 0.060, max 0.952, mean 0.529
# Preds: min 0.345, max 0.697, mean 0.520
# Loss: 0.011290350928902626 | Total grad sum: 43.65304649807513
#
# === Diagnostics epoch 10 ===
# Images: min -2.118, max 2.047, mean -0.218
# Keypoints: min 0.049, max 0.980, mean 0.535
# Preds: min 0.342, max 0.700, mean 0.521
# Loss: 0.012107035145163536 | Total grad sum: 52.35706056840718
#
# === Diagnostics epoch 10 ===
# Images: min -2.118, max 2.013, mean -0.552
# Keypoints: min 0.062, max 0.939, mean 0.503
# Preds: min 0.339, max 0.704, mean 0.521
# Loss: 0.014097128063440323 | Total grad sum: 55.663473051041365
#
# === Diagnostics epoch 11 ===
# Images: min -2.118, max 2.047, mean 0.182
# Keypoints: min 0.046, max 0.955, mean 0.515
# Preds: min 0.335, max 0.706, mean 0.522
# Loss: 0.012662281282246113 | Total grad sum: 60.82879780232906
#
# === Diagnostics epoch 11 ===
# Images: min -2.118, max 1.786, mean -0.660
# Keypoints: min 0.031, max 0.978, mean 0.520
# Preds: min 0.332, max 0.709, mean 0.522
# Loss: 0.017065562307834625 | Total grad sum: 32.27344891987741
#
# === Diagnostics epoch 11 ===
# Images: min -2.118, max 2.082, mean -0.335
# Keypoints: min 0.049, max 0.980, mean 0.536
# Preds: min 0.330, max 0.711, mean 0.522
# Loss: 0.018779516220092773 | Total grad sum: 25.875884047709405
#
# === Diagnostics epoch 11 ===
# Images: min -2.118, max 2.013, mean -0.548
# Keypoints: min 0.060, max 0.952, mean 0.525
# Preds: min 0.327, max 0.714, mean 0.522
# Loss: 0.008766480721533298 | Total grad sum: 41.837725477293134
#
# === Diagnostics epoch 12 ===
# Images: min -2.118, max 2.013, mean -0.480
# Keypoints: min 0.060, max 0.939, mean 0.531
# Preds: min 0.324, max 0.716, mean 0.523
# Loss: 0.01071805041283369 | Total grad sum: 51.59775739349425
#
# === Diagnostics epoch 12 ===
# Images: min -2.118, max 2.082, mean -0.057
# Keypoints: min 0.049, max 0.980, mean 0.534
# Preds: min 0.322, max 0.718, mean 0.523
# Loss: 0.01699402742087841 | Total grad sum: 31.121791949495673
#
# === Diagnostics epoch 12 ===
# Images: min -2.118, max 2.047, mean -0.034
# Keypoints: min 0.046, max 0.952, mean 0.512
# Preds: min 0.320, max 0.720, mean 0.523
# Loss: 0.01218308787792921 | Total grad sum: 40.89130614697933
#
# === Diagnostics epoch 12 ===
# Images: min -2.118, max 1.960, mean -0.790
# Keypoints: min 0.031, max 0.978, mean 0.519
# Preds: min 0.317, max 0.722, mean 0.523
# Loss: 0.015411564148962498 | Total grad sum: 27.23640623036772
#
# === Diagnostics epoch 13 ===
# Images: min -2.118, max 1.960, mean -0.474
# Keypoints: min 0.060, max 0.938, mean 0.524
# Preds: min 0.315, max 0.725, mean 0.524
# Loss: 0.010476757772266865 | Total grad sum: 49.76101300120354
#
# === Diagnostics epoch 13 ===
# Images: min -2.118, max 2.047, mean -0.293
# Keypoints: min 0.046, max 0.955, mean 0.521
# Preds: min 0.313, max 0.726, mean 0.524
# Loss: 0.008644516579806805 | Total grad sum: 49.62813316471875
#
# === Diagnostics epoch 13 ===
# Images: min -2.118, max 2.082, mean 0.129
# Keypoints: min 0.049, max 0.980, mean 0.539
# Preds: min 0.311, max 0.728, mean 0.524
# Loss: 0.016882020980119705 | Total grad sum: 35.96835333481431
#
# === Diagnostics epoch 13 ===
# Images: min -2.118, max 1.995, mean -0.723
# Keypoints: min 0.031, max 0.978, mean 0.513
# Preds: min 0.308, max 0.730, mean 0.524
# Loss: 0.017944062128663063 | Total grad sum: 24.674596905708313
#
# === Diagnostics epoch 14 ===
# Images: min -2.118, max 2.047, mean -0.325
# Keypoints: min 0.046, max 0.936, mean 0.511
# Preds: min 0.306, max 0.732, mean 0.524
# Loss: 0.013502410613000393 | Total grad sum: 57.832074945792556
#
# === Diagnostics epoch 14 ===
# Images: min -2.118, max 1.995, mean -0.043
# Keypoints: min 0.031, max 0.978, mean 0.514
# Preds: min 0.305, max 0.733, mean 0.524
# Loss: 0.013343934901058674 | Total grad sum: 34.17323079239577
#
# === Diagnostics epoch 14 ===
# Images: min -2.118, max 2.082, mean 0.083
# Keypoints: min 0.060, max 0.939, mean 0.531
# Preds: min 0.303, max 0.735, mean 0.525
# Loss: 0.016744965687394142 | Total grad sum: 22.42232062574476
#
# === Diagnostics epoch 14 ===
# Images: min -2.118, max 1.995, mean -1.076
# Keypoints: min 0.049, max 0.980, mean 0.541
# Preds: min 0.301, max 0.737, mean 0.525
# Loss: 0.009141084738075733 | Total grad sum: 26.741848949342966
#
# === Diagnostics epoch 15 ===
# Images: min -2.118, max 2.047, mean -0.156
# Keypoints: min 0.031, max 0.978, mean 0.506
# Preds: min 0.299, max 0.738, mean 0.525
# Loss: 0.017527662217617035 | Total grad sum: 22.6507337000221
#
# === Diagnostics epoch 15 ===
# Images: min -2.118, max 2.047, mean 0.178
# Keypoints: min 0.046, max 0.955, mean 0.517
# Preds: min 0.298, max 0.740, mean 0.525
# Loss: 0.0075701093301177025 | Total grad sum: 41.92747474089265
#
# === Diagnostics epoch 15 ===
# Images: min -2.118, max 2.082, mean -0.445
# Keypoints: min 0.060, max 0.952, mean 0.543
# Preds: min 0.296, max 0.741, mean 0.525
# Loss: 0.0161124374717474 | Total grad sum: 18.368639660533518
#
# === Diagnostics epoch 15 ===
# Images: min -2.118, max 1.960, mean -0.939
# Keypoints: min 0.049, max 0.980, mean 0.531
# Preds: min 0.294, max 0.743, mean 0.525
# Loss: 0.010643343441188335 | Total grad sum: 20.720681476406753
#
# === Diagnostics epoch 16 ===
# Images: min -2.118, max 1.995, mean -0.290
# Keypoints: min 0.062, max 0.918, mean 0.512
# Preds: min 0.293, max 0.744, mean 0.525
# Loss: 0.010772044770419598 | Total grad sum: 52.96758768707514
#
# === Diagnostics epoch 16 ===
# Images: min -2.118, max 2.047, mean -0.149
# Keypoints: min 0.046, max 0.938, mean 0.516
# Preds: min 0.291, max 0.745, mean 0.525
# Loss: 0.011849605478346348 | Total grad sum: 54.47143153846264
#
# === Diagnostics epoch 16 ===
# Images: min -2.118, max 2.047, mean -0.458
# Keypoints: min 0.031, max 0.978, mean 0.526
# Preds: min 0.290, max 0.746, mean 0.525
# Loss: 0.013265321962535381 | Total grad sum: 50.834694385528564
#
# === Diagnostics epoch 16 ===
# Images: min -2.118, max 2.082, mean -0.465
# Keypoints: min 0.049, max 0.980, mean 0.542
# Preds: min 0.289, max 0.747, mean 0.525
# Loss: 0.015410095453262329 | Total grad sum: 52.31013451516628
#
# === Diagnostics epoch 17 ===
# Images: min -2.118, max 2.082, mean 0.245
# Keypoints: min 0.046, max 0.952, mean 0.527
# Preds: min 0.288, max 0.748, mean 0.525
# Loss: 0.017083194106817245 | Total grad sum: 38.12864168360829
#
# === Diagnostics epoch 17 ===
# Images: min -2.118, max 1.856, mean -0.888
# Keypoints: min 0.031, max 0.980, mean 0.538
# Preds: min 0.286, max 0.750, mean 0.525
# Loss: 0.013863098807632923 | Total grad sum: 39.666412711143494
#
# === Diagnostics epoch 17 ===
# Images: min -2.118, max 1.995, mean -0.471
# Keypoints: min 0.062, max 0.936, mean 0.518
# Preds: min 0.285, max 0.751, mean 0.525
# Loss: 0.01122237741947174 | Total grad sum: 55.36367056518793
#
# === Diagnostics epoch 17 ===
# Images: min -2.118, max 2.013, mean -0.247
# Keypoints: min 0.079, max 0.939, mean 0.513
# Preds: min 0.283, max 0.752, mean 0.526
# Loss: 0.008424663916230202 | Total grad sum: 27.043715144507587
#
# === Diagnostics epoch 18 ===
# Images: min -2.118, max 1.960, mean -0.337
# Keypoints: min 0.057, max 0.955, mean 0.525
# Preds: min 0.282, max 0.753, mean 0.526
# Loss: 0.007171649020165205 | Total grad sum: 24.58551373705268
#
# === Diagnostics epoch 18 ===
# Images: min -2.118, max 2.047, mean -0.324
# Keypoints: min 0.049, max 0.980, mean 0.527
# Preds: min 0.281, max 0.754, mean 0.526
# Loss: 0.011532195843756199 | Total grad sum: 26.42814940586686
#
# === Diagnostics epoch 18 ===
# Images: min -2.118, max 2.082, mean -0.656
# Keypoints: min 0.031, max 0.978, mean 0.532
# Preds: min 0.280, max 0.755, mean 0.526
# Loss: 0.022557033225893974 | Total grad sum: 48.545715084299445
#
# === Diagnostics epoch 18 ===
# Images: min -2.118, max 2.047, mean -0.044
# Keypoints: min 0.046, max 0.952, mean 0.512
# Preds: min 0.279, max 0.756, mean 0.526
# Loss: 0.008876857347786427 | Total grad sum: 36.069137420505285
#
# === Diagnostics epoch 19 ===
# Images: min -2.118, max 2.082, mean -0.512
# Keypoints: min 0.060, max 0.952, mean 0.538
# Preds: min 0.278, max 0.757, mean 0.526
# Loss: 0.015407527796924114 | Total grad sum: 29.655208916403353
#
# === Diagnostics epoch 19 ===
# Images: min -2.118, max 1.769, mean -0.735
# Keypoints: min 0.031, max 0.978, mean 0.535
# Preds: min 0.276, max 0.758, mean 0.526
# Loss: 0.013940994627773762 | Total grad sum: 16.82181493099779
#
# === Diagnostics epoch 19 ===
# Images: min -2.118, max 2.047, mean 0.003
# Keypoints: min 0.046, max 0.980, mean 0.516
# Preds: min 0.275, max 0.759, mean 0.526
# Loss: 0.008643877692520618 | Total grad sum: 37.164285220205784
#
# === Diagnostics epoch 19 ===
# Images: min -2.118, max 2.047, mean -0.117
# Keypoints: min 0.083, max 0.931, mean 0.507
# Preds: min 0.274, max 0.760, mean 0.526
# Loss: 0.011780770495533943 | Total grad sum: 48.340208208188415

# %%
IMAGENET_MEAN = np.array([0.485, 0.456, 0.406])
IMAGENET_STD  = np.array([0.229, 0.224, 0.225])
def inspect_data(img_tensor, preds, gt=None):
    img = img_tensor.permute(1,2,0).cpu().numpy()
    img = img * IMAGENET_STD + IMAGENET_MEAN   # denormalize
    img = (img * 255).clip(0,255).astype(np.uint8)
    img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)

    # Draw predictions
    for i, (x, y) in enumerate(preds):
        x, y = int(x), int(y)
        cv2.circle(img, (x,y), 4, (0,0,255), -1)   # Red = prediction
        cv2.putText(img, str(i), (x+5, y-5),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,255,0), 1, cv2.LINE_AA)

    # Draw ground truth if provided
    if gt is not None:
        for i, (x, y) in enumerate(gt):
            x, y = int(x), int(y)
            cv2.circle(img, (x,y), 4, (255,0,0), 1)   # Blue = ground truth

    cv2.imshow("Debug", img)
    cv2.waitKey(1)
    key = cv2.waitKey(0)
    if key == ord('q'):
        cv2.destroyAllWindows()
        return False
    return True

model.eval()
with torch.no_grad():
    for images, keypoints in val_loader:
        images = images.to(device)
        keypoints = keypoints.to(device)
        preds = model(images)
        preds_px = preds.view(-1, NUM_LANDMARKS, 2) * 224
        keypoints_px = keypoints.view(-1, NUM_LANDMARKS, 2) * 224

        inspect_data(images[0].cpu(), preds_px[0].cpu().numpy(), keypoints_px[0].cpu().numpy())
        break  # only visualize first batch/image
